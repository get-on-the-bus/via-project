# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
csv_list = [
    '../resource_files/census_data/acs5_B01001_SexByAge.csv', 
    '../resource_files/census_data/acs5_B03002_HispanicOrigin.csv', 
    '../resource_files/census_data/acs5_B08134_TransportByTravelTime.csv', 
    '../resource_files/census_data/acs5_B08301_TransportationToWork.csv', 
    '../resource_files/census_data/acs5_B08302_LeaveTimeForWork.csv', 
    '../resource_files/census_data/acs5_B08303_TravelTimeToWork.csv', 
    '../resource_files/census_data/acs5_B19001_HouseholdIncome.csv', 
    '../resource_files/census_data/acs5_B1905x_IncomeTypeByHousehold.csv', 
    '../resource_files/census_data/acs5_B24080_SexByWorkerClass.csv', 
    '../resource_files/census_data/acs5_C17002_RatioIncomePoverty.csv', 
]

# %%
def wrangle_acs5(src):
    df1 = pd.read_json(src)
    df1.columns = df1.iloc[0]
    df1 = df1[1:].copy()
    df1['block_group'] = df1.state.map(str) + df1.county.map(str) + df1.tract.map(str) + df1['block group'].map(str)
    df1=df1.drop(columns=['state','county','tract','block group']).set_index('block_group').astype('float')
    return df1

# %%
df = pd.read_csv(csv_list[0]).set_index('block_group')

# %%
df.head()
# Out:
#               B01001_001E  B01001_002E  B01001_026E  B01001_001E_W  \
# block_group
# 480291805031        659.0        417.0        242.0          454.0
# 480291805032       1942.0        806.0       1136.0         1319.0
# 480291704013       1676.0        663.0       1013.0          838.0
# 480291704012        730.0        384.0        346.0          306.0
# 480291914061       2612.0       1229.0       1383.0         1546.0
#
#               B01001_002E_W  B01001_026E_W  B01001_001E_N  B01001_002E_N  \
# block_group
# 480291805031          279.0          175.0          205.0          138.0
# 480291805032          553.0          766.0          623.0          253.0
# 480291704013          327.0          511.0          838.0          336.0
# 480291704012          123.0          183.0          424.0          261.0
# 480291914061          701.0          845.0         1066.0          528.0
#
#               B01001_026E_N
# block_group
# 480291805031           67.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1084 entries, 480291805031 to 480291922002
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   B01001_001E    1084 non-null   float64
#  1   B01001_002E    1084 non-null   float64
#  2   B01001_026E    1084 non-null   float64
#  3   B01001_001E_W  1084 non-null   float64
#  4   B01001_002E_W  1084 non-null   float64
#  5   B01001_026E_W  1084 non-null   float64
#  6   B01001_001E_N  1084 non-null   float64
#  7   B01001_002E_N  1084 non-null   float64
#  8   B01001_026E_N  1084 non-null   float64
# dtypes: float64(9)
# memory usage: 84.7 KB

# %%
df = pd.read_csv(csv_list[0]).set_index('block_group')
print(csv_list[0])
print(df.columns)
for csv in csv_list[1:]:
    dfj = pd.read_csv(csv).set_index('block_group')
    print(csv)
    print(dfj.columns)
    df = df.join(dfj,how='left')
# Out:
# ../resource_files/census_data/acs5_B01001_SexByAge.csv
# Index(['B01001_001E', 'B01001_002E', 'B01001_026E', 'B01001_001E_W',
#        'B01001_002E_W', 'B01001_026E_W', 'B01001_001E_N', 'B01001_002E_N',
#        'B01001_026E_N'],
#       dtype='object')
# ../resource_files/census_data/acs5_B03002_HispanicOrigin.csv
# Index(['B03002_001E', 'B03002_002E', 'B03002_003E', 'B03002_004E',
#        'B03002_006E', 'B03002_002E_O', 'B03002_012E'],
#       dtype='object')
# ../resource_files/census_data/acs5_B08134_TransportByTravelTime.csv
# Index(['B08134_001E', 'B08134_003E_M', 'B08134_006E_M', 'B08134_009E_M',
#        'B08134_010E', 'B08134_011E', 'B08134_013E_M', 'B08134_016E_M',
#        'B08134_019E_M', 'B08134_020E', 'B08134_071E', 'B08134_073E_M',
#        'B08134_076E_M', 'B08134_079E_M', 'B08134_080E'],
#       dtype='object')
# ../resource_files/census_data/acs5_B08301_TransportationToWork.csv
# Index(['B08301_001E', 'B08301_002E', 'B08301_003E', 'B08301_004E',
# ...

# %%
# df = df.join(df1,how='left')

# %%
df.head()
# Out:
#               B01001_001E  B01001_002E  B01001_026E  B01001_001E_W  \
# block_group
# 480291805031        659.0        417.0        242.0          454.0
# 480291805032       1942.0        806.0       1136.0         1319.0
# 480291704013       1676.0        663.0       1013.0          838.0
# 480291704012        730.0        384.0        346.0          306.0
# 480291914061       2612.0       1229.0       1383.0         1546.0
#
#               B01001_002E_W  B01001_026E_W  B01001_001E_N  B01001_002E_N  \
# block_group
# 480291805031          279.0          175.0          205.0          138.0
# 480291805032          553.0          766.0          623.0          253.0
# 480291704013          327.0          511.0          838.0          336.0
# 480291704012          123.0          183.0          424.0          261.0
# 480291914061          701.0          845.0         1066.0          528.0
#
#               B01001_026E_N  B03002_001E  B03002_002E  B03002_003E  \
# block_group
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1084 entries, 480291805031 to 480291922002
# Columns: 105 entries, B01001_001E to C17002_008E
# dtypes: float64(105)
# memory usage: 937.7 KB

# %%
df.sum()
# Out:
# B01001_001E       1.925865e+06
# B01001_002E       9.500300e+05
# B01001_026E       9.758350e+05
# B01001_001E_W     1.202936e+06
# B01001_002E_W     5.994430e+05
# B01001_026E_W     6.034930e+05
# B01001_001E_N     7.229290e+05
# B01001_002E_N     3.505870e+05
# B01001_026E_N     3.723420e+05
# B03002_001E       1.925865e+06
# B03002_002E       7.703600e+05
# B03002_003E       5.394350e+05
# B03002_004E       1.364110e+05
# B03002_006E       5.251300e+04
# B03002_002E_O     4.200100e+04
# B03002_012E       1.155505e+06
# B08134_001E       8.517260e+05
# B08134_003E_M     1.766100e+05
# B08134_006E_M     3.706940e+05
# B08134_009E_M     2.587870e+05
# B08134_010E       4.563500e+04
# B08134_011E       8.014280e+05
# B08134_013E_M     1.599540e+05
# B08134_016E_M     3.592510e+05
# B08134_019E_M     2.463370e+05
# B08134_020E       3.588600e+04
# B08134_071E       2.150700e+04
# B08134_073E_M     1.647000e+03
# B08134_076E_M     4.114000e+03
# B08134_079E_M     7.646000e+03
# ...

# %%
df.columns
# Out:
# Index(['B01001_001E', 'B01001_002E', 'B01001_026E', 'B01001_001E_W',
#        'B01001_002E_W', 'B01001_026E_W', 'B01001_001E_N', 'B01001_002E_N',
#        'B01001_026E_N', 'B03002_001E',
#        ...
#        'B24080_016E', 'B24080_019E_M', 'B24080_020E', 'B24080_021E',
#        'C17002_001E', 'C17002_002E', 'C17002_003E', 'C17002_005E_M',
#        'C17002_007E_M', 'C17002_008E'],
#       dtype='object', length=105)

# %%
df_key = df.copy()

# %%
df_fields = pd.read_csv('../resource_files/census_data/census_field_names.csv').set_index('field_code')

# %%
df_fields.head()
# Out:
#               group_code  group_name                            full_text  \
# field_code
# B01001_001E       B01001  Sex By Age                       Estimate|Total
# B01001_001E_N     B01001  Sex By Age       Estimate|Total|Not Working Age
# B01001_001E_W     B01001  Sex By Age           Estimate|Total|Working Age
# B01001_002E       B01001  Sex By Age                  Estimate|Total|Male
# B01001_002E_N     B01001  Sex By Age  Estimate|Total|Male|Not Working Age
#
#               is_orig disposition              short_text
# field_code
# B01001_001E         y           k             sex_age_tot
# B01001_001E_N       n           k    sex_not_work_age_tot
# B01001_001E_W       n           k        sex_work_age_tot
# B01001_002E         y           k           sex_age_tot_m
# B01001_002E_N       n           k  sex_not_work_age_tot_m

# %%
df_name = df_key.rename(columns=df_fields.short_text).copy()

# %%
df_name.head()
# Out:
#               sex_age_tot  sex_age_tot_m  sex_age_tot_f  sex_work_age_tot  \
# block_group
# 480291805031        659.0          417.0          242.0             454.0
# 480291805032       1942.0          806.0         1136.0            1319.0
# 480291704013       1676.0          663.0         1013.0             838.0
# 480291704012        730.0          384.0          346.0             306.0
# 480291914061       2612.0         1229.0         1383.0            1546.0
#
#               sex_work_age_tot_m  sex_work_age_tot_f  sex_not_work_age_tot  \
# block_group
# 480291805031               279.0               175.0                 205.0
# 480291805032               553.0               766.0                 623.0
# 480291704013               327.0               511.0                 838.0
# 480291704012               123.0               183.0                 424.0
# 480291914061               701.0               845.0                1066.0
#
# ...

# %%
for col in df_name.columns:
    print(col)
# Out:
# sex_age_tot
# sex_age_tot_m
# sex_age_tot_f
# sex_work_age_tot
# sex_work_age_tot_m
# sex_work_age_tot_f
# sex_not_work_age_tot
# sex_not_work_age_tot_m
# sex_not_work_age_tot_f
# race_tot
# non_hisp_total
# race_tot_w
# race_tot_b
# race_tot_a
# non_hisp_oth
# hisp_tot
# trans_means_time_tot
# trans_means_time_tot_00_14
# trans_means_time_tot_15_29
# trans_means_time_tot_30_59
# trans_means_time_tot_60_plus
# trans_means_time_car
# trans_means_time_car_00_14
# trans_means_time_car_15_29
# trans_means_time_car_30_59
# trans_means_time_car_60_plus
# trans_means_time_bus
# trans_bus_time_00_14
# trans_bus_time_15_29
# trans_bus_time_tot_30_59
# trans_means_time_bus_60_plus
# trans_means_tot
# trans_car
# trans_car_sov
# trans_car_hov
# trans_bus
# trans_wfh
# time_leave_to_work_tot
# time_leave_to_work_00_05
# time_leave_to_work_05_06
# time_leave_to_work_06_07
# time_leave_to_work_07_08
# time_leave_to_work_08_09
# time_leave_to_work_09_10
# time_leave_to_work_10_12
# ...

# %%
col_merge = dict(zip(df_key.columns, df_name.columns))

# %%
col_merge
# Out:
# {'B01001_001E': 'sex_age_tot',
#  'B01001_002E': 'sex_age_tot_m',
#  'B01001_026E': 'sex_age_tot_f',
#  'B01001_001E_W': 'sex_work_age_tot',
#  'B01001_002E_W': 'sex_work_age_tot_m',
#  'B01001_026E_W': 'sex_work_age_tot_f',
#  'B01001_001E_N': 'sex_not_work_age_tot',
#  'B01001_002E_N': 'sex_not_work_age_tot_m',
#  'B01001_026E_N': 'sex_not_work_age_tot_f',
#  'B03002_001E': 'race_tot',
#  'B03002_002E': 'non_hisp_total',
#  'B03002_003E': 'race_tot_w',
#  'B03002_004E': 'race_tot_b',
#  'B03002_006E': 'race_tot_a',
#  'B03002_002E_O': 'non_hisp_oth',
#  'B03002_012E': 'hisp_tot',
#  'B08134_001E': 'trans_means_time_tot',
#  'B08134_003E_M': 'trans_means_time_tot_00_14',
#  'B08134_006E_M': 'trans_means_time_tot_15_29',
#  'B08134_009E_M': 'trans_means_time_tot_30_59',
#  'B08134_010E': 'trans_means_time_tot_60_plus',
#  'B08134_011E': 'trans_means_time_car',
#  'B08134_013E_M': 'trans_means_time_car_00_14',
#  'B08134_016E_M': 'trans_means_time_car_15_29',
# ...

# %%
df_key_csv = '../resource_files/census_data/acs5_key.csv'
df_name_csv = '../resource_files/census_data/acs5_name.csv'

# %%
df_key.to_csv(df_key_csv, header=True, index=True, index_label='block_group')

# %%
df_name.to_csv(df_name_csv, header=True, index=True, index_label='block_group')

# %%
rdf_key=pd.read_csv(df_key_csv).set_index('block_group')

# %%
rdf_name=pd.read_csv(df_name_csv).set_index('block_group')

# %%
rdf_key.head()
# Out:
#               B01001_001E  B01001_002E  B01001_026E  B01001_001E_W  \
# block_group
# 480291805031        659.0        417.0        242.0          454.0
# 480291805032       1942.0        806.0       1136.0         1319.0
# 480291704013       1676.0        663.0       1013.0          838.0
# 480291704012        730.0        384.0        346.0          306.0
# 480291914061       2612.0       1229.0       1383.0         1546.0
#
#               B01001_002E_W  B01001_026E_W  B01001_001E_N  B01001_002E_N  \
# block_group
# 480291805031          279.0          175.0          205.0          138.0
# 480291805032          553.0          766.0          623.0          253.0
# 480291704013          327.0          511.0          838.0          336.0
# 480291704012          123.0          183.0          424.0          261.0
# 480291914061          701.0          845.0         1066.0          528.0
#
#               B01001_026E_N  B03002_001E  B03002_002E  B03002_003E  \
# block_group
# ...

# %%
rdf_name.head()
# Out:
#               sex_age_tot  sex_age_tot_m  sex_age_tot_f  sex_work_age_tot  \
# block_group
# 480291805031        659.0          417.0          242.0             454.0
# 480291805032       1942.0          806.0         1136.0            1319.0
# 480291704013       1676.0          663.0         1013.0             838.0
# 480291704012        730.0          384.0          346.0             306.0
# 480291914061       2612.0         1229.0         1383.0            1546.0
#
#               sex_work_age_tot_m  sex_work_age_tot_f  sex_not_work_age_tot  \
# block_group
# 480291805031               279.0               175.0                 205.0
# 480291805032               553.0               766.0                 623.0
# 480291704013               327.0               511.0                 838.0
# 480291704012               123.0               183.0                 424.0
# 480291914061               701.0               845.0                1066.0
#
# ...
