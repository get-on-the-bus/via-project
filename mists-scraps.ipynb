# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('https://storage.googleapis.com/sa_via_data/BusOnTimePerformance.xlsx')

# %%
df
# Out:
#       ServiceDateTime  Route                          RouteName  \
# 0          2018-01-01      2                             BLANCO
# 1          2018-01-01      3                     SAN PEDRO SKIP
# 2          2018-01-01      4                 SAN PEDRO Frequent
# 3          2018-01-01      5                         McCULLOUGH
# 4          2018-01-01      8                         N ST MARYS
# ...               ...    ...                                ...
# 35326      2019-01-30    647        North Star / Harry Wurzbach
# 35327      2019-01-30    648             North Star / Stone Oak
# 35328      2019-01-30    651       Deco District / Castle Hills
# 35329      2019-01-30    660  NW Vista College / University P&R
# 35330      2019-01-30    672      TAMUSA / Madla Transit Center
#
#        EarlyDeparture  OnTime  LateArrival  Missing  TimePointCount    OTP  \
# 0                  23     373           65       59             461  80.91
# ...
