# %%
import pandas as pd

# %%
df1 = pd.read_('BusFareBoxActivity_2020.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-f854cd5feb51> in <module>
# ----> 1 df1 = pd.read_csv('BusFareBoxActivity_2020.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
df = pd.read_excel('BusFareBoxActivity_2020.csv')

# %%
df2019 = df[df.ServiceDateTime >= '2019-01-01']

# %%
df2019.shape
# Out:
# (23039, 11)

# %%
df2019[df2019.RouteName.isnull()]
# Out:
#       ServiceDateTime  Route RouteName  CurrentRevenue  Ridership  TokenCount  \
# 67123      2019-01-07      1       NaN            0.11          0           0
# 67176      2019-01-07    103       NaN         1046.17       3297           1
# 67177      2019-01-07    276       NaN            9.77         25           0
# 67179      2019-01-07    501       NaN          238.94        805           0
# 67219      2019-01-07    672       NaN           91.18        219           0
# ...               ...    ...       ...             ...        ...         ...
# 89617      2020-01-09    268       NaN            2.65          7           0
# 89618      2020-01-09    276       NaN            0.00          9           0
# 89619      2020-01-09    277       NaN            1.35          7           0
# 89620      2020-01-09    288       NaN            1.35          7           0
# 89621      2020-01-09    296       NaN            1.00         11           0
#
# ...
